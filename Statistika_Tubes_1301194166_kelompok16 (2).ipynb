# %% [markdown]
# Kelompok XVI
# ---
# Kelas : IF-43-GAB05
#
# Nama Dosen: Wawan Setiawan
#
# Anggota:
#
# 1.  Muhammad Fauzan Avidiansyah (1301194166)
# 2. Muhammad Jundi Aminullah (1301193298)
# 3. Hazim Ismail (1301194149)
# 4.Tubagus Bintang Alvie Azkiyya (1301194269)

# %%
library('tidyverse') #install library
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.3     ✔ purrr   0.3.4
# ✔ tibble  3.0.5     ✔ dplyr   1.0.3
# ✔ tidyr   1.1.2     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
install.packages('mlbench') #install package untuk machine learning
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
BankChurners = read.csv("BankChurners.csv") #memasukan data csv
# Out:
# Warning message in file(file, "rt"):
# “cannot open file 'BankChurners.csv': No such file or directory”
# Error in file(file, "rt"): cannot open the connection
# Traceback:
#
# 1. read.csv("BankChurners.csv")
# 2. read.table(file = file, header = header, sep = sep, quote = quote,
#  .     dec = dec, fill = fill, comment.char = comment.char, ...)
# 3. file(file, "rt")

# %%
head(BankChurners) #menampilkan data dalam bentuk tabel
# Out:
#   CLIENTNUM Attrition_Flag    Customer_Age Gender Dependent_count
# 1 768805383 Existing Customer 45           M      3
# 2 818770008 Existing Customer 49           F      5
# 3 713982108 Existing Customer 51           M      3
# 4 769911858 Existing Customer 40           F      4
# 5 709106358 Existing Customer 40           M      3
# 6 713061558 Existing Customer 44           M      2
#   Education_Level Marital_Status Income_Category Card_Category Months_on_book ⋯
# 1 High School     Married        $60K - $80K     Blue          39             ⋯
# 2 Graduate        Single         Less than $40K  Blue          44             ⋯
# 3 Graduate        Married        $80K - $120K    Blue          36             ⋯
# 4 High School     Unknown        Less than $40K  Blue          34             ⋯
# 5 Uneducated      Married        $60K - $80K     Blue          21             ⋯
# 6 Graduate        Married        $40K - $60K     Blue          36             ⋯
# ...

# %%
mean(BankChurners$Months_on_book) #mencari rata-rata
# Out:
# [1] 35.92841

# %%
median(BankChurners$Months_on_book) #mencari nilai tengah
# Out:
# [1] 36

# %%
min(BankChurners$Months_on_book) #mencari nilai terkecil
# Out:
# [1] 13

# %%
max(BankChurners$Months_on_book) #mencari nilai terbesar
# Out:
# [1] 56

# %%
summary(BankChurners) #menampilkan ukuran penyebaran secara lengkap (mean,median,quartil)
# Out:
#    CLIENTNUM         Attrition_Flag      Customer_Age      Gender
#  Min.   :708082083   Length:10127       Min.   :26.00   Length:10127
#  1st Qu.:713036770   Class :character   1st Qu.:41.00   Class :character
#  Median :717926358   Mode  :character   Median :46.00   Mode  :character
#  Mean   :739177606                      Mean   :46.33
#  3rd Qu.:773143533                      3rd Qu.:52.00
#  Max.   :828343083                      Max.   :73.00
#  Dependent_count Education_Level    Marital_Status     Income_Category
#  Min.   :0.000   Length:10127       Length:10127       Length:10127
#  1st Qu.:1.000   Class :character   Class :character   Class :character
#  Median :2.000   Mode  :character   Mode  :character   Mode  :character
#  Mean   :2.346
#  3rd Qu.:3.000
#  Max.   :5.000
#  Card_Category      Months_on_book  Total_Relationship_Count
#  Length:10127       Min.   :13.00   Min.   :1.000
#  Class :character   1st Qu.:31.00   1st Qu.:3.000
# ...

# %%
cor(BankChurners$Customer_Age, BankChurners$Months_on_book) #nilai korelasi
# Out:
# [1] 0.7889124

# %% [markdown]
# Fungsi ini digunakan untuk menentukan korelasi antara Customer_Age dengan Months_on_book

# %%
cor.test(BankChurners$Customer_Age, BankChurners$Months_on_book) #uji korelasi
# Out:
# 	Pearson's product-moment correlation
#
# data:  BankChurners$Customer_Age and BankChurners$Months_on_book
# t = 129.18, df = 10125, p-value < 2.2e-16
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  0.7814428 0.7961558
# sample estimates:
#       cor
# 0.7889124

# %% [markdown]
# Fungsi ini digunakan untuk menampilkan ukuran penyebaran data (seperti kuartil) dan pemusatan data

# %%
plot(BankChurners$Customer_Age,BankChurners$Months_on_book, type = "p") #menampilkan scatter plot
# Out:
# plot without title

# %% [markdown]
# menampilkan scatter plot. pola scatter plot diatas adalah pola positif

# %%
hist(BankChurners$Months_Inactive_12_mon, main="Customer inactive selama setahun",col ="Pink")  #menampilkan histogram
# Out:
# Plot with title “Customer inactive selama setahun”

# %%
plot(density(BankChurners$Customer_Age),col = "purple",main="Umur Customer") #menampilkan density
# Out:
# Plot with title “Umur Customer”

# %%
hist(BankChurners$Customer_Age,freq = FALSE, col = "green", main="Umur Customer") #menampilkan histogram
# Out:
# Plot with title “Umur Customer”

# %%
boxplot(BankChurners$Months_Inactive_12_mon, col= "light blue", main= "Months_on_book")
# Out:
# Plot with title “Months_on_book”

# %% [markdown]
# Fungsi ini digunakan untuk menapilkan box plot yang merupakan visualisasi dari penyebaran data (seperti kuartil, maksimum, minimum, dan pencilan). Penyebaran data yang ditampilkan dalam box plot ini adalah Months_on_book.

# %%
barplot(BankChurners[,"Customer_Age"]) #menampilkan barplot yang divisualisasikan ke kanan
# Out:
# plot without title

# %% [markdown]
# Fungsi ini digunakan untuk memvisualisasikan banyak data dari kategori Months_on_book dengan menggunakan diagram batang

# %% [markdown]
# Kesimpulan
#
# Pada bagian histogram rata-rata customer untuk Bank Churners memiliki usia dengan rentang 45-50 tahun dimana dari data yang telah di eksplorasi tersebut nantinya dapat membuat perusahaan tahu rentang usia pengguna dari product nya. dan dari visualisasi data yang lain diatas juga kita dapat melihat bahwa rata-rata usia customer yang menggunakan product adalah 45-50.
